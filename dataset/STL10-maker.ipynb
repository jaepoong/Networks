# %%
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.nn.functional as F
from torchvision import transforms,datasets
import torchvision
import os

path2data='./dataset/STL10/stl10_binary'
'''
if not os.path.exists(path2data):
  os.mkdir(path2data)

train_ds=datasets.STL10(root=path2data,
                        split='train',
                        download=True,
                        transform=transforms.ToTensor())
test_ds=datasets.STL10(root=path2data,
                       split='test',
                       download=True,
                       transform=transforms.ToTensor())'''
# Out:
# "\nif not os.path.exists(path2data):\n  os.mkdir(path2data)\n\ntrain_ds=datasets.STL10(root=path2data,\n                        split='train',\n                        download=True,\n                        transform=transforms.ToTensor())\ntest_ds=datasets.STL10(root=path2data,\n                       split='test',\n                       download=True,\n                       transform=transforms.ToTensor())"

# %%
# %cd /content/drive/MyDrive/데이터사이언스/CnnNetworks
# Out:
# /content/drive/MyDrive/데이터사이언스/CnnNetworks

# %%
trainset = torchvision.datasets.ImageFolder(root=path2data, transform=transforms.ToTensor())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-18-f3d7ccf67732> in <module>()
# ----> 1 trainset = torchvision.datasets.ImageFolder(root=path2data, transform=transforms.ToTensor())
#
# /usr/local/lib/python3.7/dist-packages/torchvision/datasets/folder.py in __init__(self, root, transform, target_transform, loader, is_valid_file)
#     311                                           transform=transform,
#     312                                           target_transform=target_transform,
# --> 313                                           is_valid_file=is_valid_file)
#     314         self.imgs = self.samples
#
# /usr/local/lib/python3.7/dist-packages/torchvision/datasets/folder.py in __init__(self, root, loader, extensions, transform, target_transform, is_valid_file)
#     143         super(DatasetFolder, self).__init__(root, transform=transform,
# ...

# %%
import torch.utils.data as data
train_loader = data.DataLoader(path2data,batch_size=64, shuffle=True)

# %%
train_loader

# %%
i=0
for data in train_loader:
  print(data)
  i+=1
  if i==1000:
    break
# Out:
# ['r', '.', 'y', '1', 'T', 'S', 'b', 'l', 'd', '/', '_', 'n', 't', 'i', 't', 'a', '0', 'e', '/', 's', '0', 'a', 'a', '/', 'L', '1', 't', 's']
