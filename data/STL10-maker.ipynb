# %%
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.nn.functional as F
from torchvision import transforms,datasets
import torchvision
import os

path2data='./dataset/STL10'
'''
if not os.path.exists(path2data):
  os.mkdir(path2data)

train_ds=datasets.STL10(root=path2data,
                        split='train',
                        download=True,
                        transform=transforms.ToTensor())
test_ds=datasets.STL10(root=path2data,
                       split='test',
                       download=True,
                       transform=transforms.ToTensor())'''
# Out:
# "\nif not os.path.exists(path2data):\n  os.mkdir(path2data)\n\ntrain_ds=datasets.STL10(root=path2data,\n                        split='train',\n                        download=True,\n                        transform=transforms.ToTensor())\ntest_ds=datasets.STL10(root=path2data,\n                       split='test',\n                       download=True,\n                       transform=transforms.ToTensor())"

# %%
# %cd /content/drive/MyDrive/데이터사이언스/CnnNetworks
# Out:
# /content/drive/MyDrive/데이터사이언스/CnnNetworks

# %%
train_ds.data.shape
# Out:
# (5000, 3, 96, 96)

# %%
import torch.utils.data as data
train_loader = data.DataLoader(path2data,batch_size=64, shuffle=True)

# %%
x_train,y_train=train_loader
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-fb49324a2f83> in <module>()
# ----> 1 x_train,y_train=train_loader
#
# ValueError: not enough values to unpack (expected 2, got 1)
